# %% [markdown]
# # Problema 1

# %%
x = 49
if x > 25:
    print('Asteroide acercandose velozmente')
else:
    print('Tod esta bien')
# Out:
# Asteroide acercandose velozmente

# %% [markdown]
# # Problema 2

# %%
x = 19
if x > 20:
    print('Se puede ver el asteroide sin problemas')
elif x == 20:
    print('Apenas y se puede ver el asteroide')
else:
    print('No se ve el asteroide')
# Out:
# No se ve el asteroide

# %% [markdown]
# # Problema 3

# %%
x = 25
y = 40
if x > 25 and y > 25:
    print('El fin del mundo llegó señores no tenemos escapatoria')
elif x >= 20:
    print('Podemos ver un bonito asteroide pasar')
elif y < 25:
    print('No se puede ver nada ni en la noche más clara')
else:
    print('No existen los asteroides al parecer')
# Out:
# Podemos ver un bonito asteroide pasar
